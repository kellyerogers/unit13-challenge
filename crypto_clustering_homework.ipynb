# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import requests
import pandas as pd
import matplotlib.pyplot as plt
import hvplot.pandas
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"
response = requests.get(url).json()

# %%
# Create a DataFrame 
# HINT: You will need to use the 'Data' key from the json response, then transpose the DataFrame.

crypto_df = pd.DataFrame(response['Data']).T
crypto_df.head()
# Out:
#          Id                  Url                         ImageUrl  \
# 42     4321   /coins/42/overview           /media/35650717/42.jpg
# 300  749869  /coins/300/overview          /media/27010595/300.png
# 365   33639  /coins/365/overview            /media/352070/365.png
# 404   21227  /coins/404/overview  /media/35650851/404-300x300.jpg
# 433  926547  /coins/433/overview          /media/34836095/433.png
#
#     ContentCreatedOn Name Symbol   CoinName         FullName  \
# 42        1427211129   42     42    42 Coin     42 Coin (42)
# 300       1517935016  300    300  300 token  300 token (300)
# 365       1480032918  365    365    365Coin    365Coin (365)
# 404       1466100361  404    404    404Coin    404Coin (404)
# 433       1541597321  433    433  433 Token  433 Token (433)
#
#                                            Description AssetTokenStatus  ...  \
# 42   Everything about 42 coin is 42 - apart from th...              N/A  ...
# 300  300 token is an ERC20 token. This Token was cr...              N/A  ...
# 365  365Coin is a Proof of Work and Proof of Stake ...              N/A  ...
# 404  404 is a PoW/PoS hybrid cryptocurrency that al...              N/A  ...
# 433  433 Token is a decentralised soccer platform t...         Finished  ...
#
#     BlockReward BlockTime AssetLaunchDate MaxSupply MktCapPenalty  \
# 42            0         0      0000-00-00         0             0
# 300           0         0      2017-07-01        -1             0
# 365         NaN       NaN             NaN       NaN           NaN
# 404           0         0      0000-00-00         0             0
# 433         NaN       NaN             NaN       NaN           NaN
#
#     PlatformType BuiltOn                        SmartContractAddress  \
# 42           NaN     NaN                                         NaN
# 300        token     ETH  0xaec98a708810414878c3bcdf46aad31ded4a4557
# 365          NaN     NaN                                         NaN
# 404          NaN     NaN                                         NaN
# 433          NaN     NaN                                         NaN
#
#     Difficulty IsUsedInDefi
# 42         NaN          NaN
# 300        NaN          NaN
# 365        NaN          NaN
# 404        NaN          NaN
# 433        NaN          NaN
#
# [5 rows x 30 columns]

# %%
# Alternatively, use the provided csv file:
file_path = Path("Resources/crypto_data.csv")

# Create a DataFrame
crypto_df = pd.read_csv(file_path, index_col=0)
crypto_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-63e4d68f7777> in <module>
#       1 # Alternatively, use the provided csv file:
# ----> 2 file_path = Path("Resources/crypto_data.csv")
#       3
#       4 # Create a DataFrame
#       5 crypto_df = pd.read_csv(file_path, index_col=0)
#
# NameError: name 'Path' is not defined

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'

crypto_df=crypto_df[['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply']]
crypto_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-d6b57828ee41> in <module>
#       2 # 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
#       3
# ----> 4 crypto_df=crypto_df[['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply']]
#       5 crypto_df.head(10)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1643             if not (self.name == "loc" and not raise_missing):
#    1644                 not_found = list(set(key) - set(ax))
# -> 1645                 raise KeyError(f"{not_found} not in index")
#    1646
#    1647             # we skip the warning on Categorical/Interval
#
# KeyError: "['TotalCoinSupply'] not in index"

# %%
# Keep only cryptocurrencies that are trading

crypto_df = crypto_df[crypto_df["IsTrading"] == True]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (4554, 30)
#           Id                   Url                           ImageUrl  \
# 42      4321    /coins/42/overview             /media/35650717/42.jpg
# 300   749869   /coins/300/overview            /media/27010595/300.png
# 365    33639   /coins/365/overview              /media/352070/365.png
# 404    21227   /coins/404/overview    /media/35650851/404-300x300.jpg
# 611    20909   /coins/611/overview  /media/35650940/611-sixeleven.png
# 808    28223   /coins/808/overview              /media/351513/808.png
# 888    29462   /coins/888/overview              /media/351639/888.png
# 1337   20824  /coins/1337/overview          /media/35520987/elite.png
# 2015    3744  /coins/2015/overview              /media/20180/2015.png
# NXT     1183   /coins/nxt/overview               /media/20627/nxt.png
#
#      ContentCreatedOn  Name Symbol   CoinName          FullName  \
# 42         1427211129    42     42    42 Coin      42 Coin (42)
# 300        1517935016   300    300  300 token   300 token (300)
# 365        1480032918   365    365    365Coin     365Coin (365)
# 404        1466100361   404    404    404Coin     404Coin (404)
# 611        1465914773   611    611  SixEleven   SixEleven (611)
# 808        1473980395   808    808        808         808 (808)
# 888        1475534352   888    888   Octocoin    Octocoin (888)
# 1337       1465838687  1337   1337  EliteCoin  EliteCoin (1337)
# 2015       1425316878  2015   2015  2015 coin  2015 coin (2015)
# NXT        1417635253   NXT    NXT        Nxt         Nxt (NXT)
#
#                                             Description AssetTokenStatus  ...  \
# 42    Everything about 42 coin is 42 - apart from th...              N/A  ...
# 300   300 token is an ERC20 token. This Token was cr...              N/A  ...
# 365   365Coin is a Proof of Work and Proof of Stake ...              N/A  ...
# 404   404 is a PoW/PoS hybrid cryptocurrency that al...              N/A  ...
# 611   611 is a Namecoin based cryptocurrency, and it...              N/A  ...
# 808   808 is a coin develop for the music community ...              N/A  ...
# 888   Octocoin is a Proof of Work cryptocurrency. It...              N/A  ...
# 1337  1337 coin was created as an experimental Proof...              N/A  ...
# 2015  Twenty15 Coin was conceived to be an asset bac...              N/A  ...
# NXT    Nxt is an open-source blockchain platform and...         Finished  ...
#
#      BlockReward BlockTime AssetLaunchDate MaxSupply MktCapPenalty  \
# 42             0         0      0000-00-00         0             0
# 300            0         0      2017-07-01        -1             0
# 365          NaN       NaN             NaN       NaN           NaN
# 404            0         0      0000-00-00         0             0
# 611          NaN       NaN             NaN       NaN           NaN
# 808            0         0      0000-00-00         0             0
# 888            0         0      0000-00-00         0             0
# 1337           0         0      0000-00-00         0             0
# 2015         NaN       NaN             NaN       NaN           NaN
# NXT            0         0      0000-00-00         0             0
#
#      PlatformType BuiltOn                        SmartContractAddress  \
# 42            NaN     NaN                                         NaN
# 300         token     ETH  0xaec98a708810414878c3bcdf46aad31ded4a4557
# 365           NaN     NaN                                         NaN
# 404           NaN     NaN                                         NaN
# 611           NaN     NaN                                         NaN
# 808           NaN     NaN                                         NaN
# 888           NaN     NaN                                         NaN
# 1337          NaN     NaN                                         NaN
# 2015          NaN     NaN                                         NaN
# NXT           NaN     NaN                                         NaN
#
#      Difficulty IsUsedInDefi
# 42          NaN          NaN
# 300         NaN          NaN
# 365         NaN          NaN
# 404         NaN          NaN
# 611         NaN          NaN
# 808         NaN          NaN
# 888         NaN          NaN
# 1337        NaN          NaN
# 2015        NaN          NaN
# NXT         NaN          NaN
#
# [10 rows x 30 columns]

# %%
# Keep only cryptocurrencies with a working algorithm

crypto_df = crypto_df[crypto_df["Algorithm"] != "N/A"]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (1464, 30)
#           Id                    Url                           ImageUrl  \
# 42      4321     /coins/42/overview             /media/35650717/42.jpg
# 365    33639    /coins/365/overview              /media/352070/365.png
# 404    21227    /coins/404/overview    /media/35650851/404-300x300.jpg
# 611    20909    /coins/611/overview  /media/35650940/611-sixeleven.png
# 808    28223    /coins/808/overview              /media/351513/808.png
# 1337   20824   /coins/1337/overview          /media/35520987/elite.png
# 2015    3744   /coins/2015/overview              /media/20180/2015.png
# NXT     1183    /coins/nxt/overview               /media/20627/nxt.png
# BTCD    4400   /coins/btcd/overview            /media/19630/btcd_1.png
# CRAIG   4425  /coins/craig/overview             /media/20022/craig.png
#
#       ContentCreatedOn   Name Symbol     CoinName            FullName  \
# 42          1427211129     42     42      42 Coin        42 Coin (42)
# 365         1480032918    365    365      365Coin       365Coin (365)
# 404         1466100361    404    404      404Coin       404Coin (404)
# 611         1465914773    611    611    SixEleven     SixEleven (611)
# 808         1473980395    808    808          808           808 (808)
# 1337        1465838687   1337   1337    EliteCoin    EliteCoin (1337)
# 2015        1425316878   2015   2015    2015 coin    2015 coin (2015)
# NXT         1417635253    NXT    NXT          Nxt           Nxt (NXT)
# BTCD        1427711372   BTCD   BTCD  BitcoinDark  BitcoinDark (BTCD)
# CRAIG       1427711632  CRAIG  CRAIG   CraigsCoin  CraigsCoin (CRAIG)
#
#                                              Description AssetTokenStatus  \
# 42     Everything about 42 coin is 42 - apart from th...              N/A
# 365    365Coin is a Proof of Work and Proof of Stake ...              N/A
# 404    404 is a PoW/PoS hybrid cryptocurrency that al...              N/A
# 611    611 is a Namecoin based cryptocurrency, and it...              N/A
# 808    808 is a coin develop for the music community ...              N/A
# 1337   1337 coin was created as an experimental Proof...              N/A
# 2015   Twenty15 Coin was conceived to be an asset bac...              N/A
# NXT     Nxt is an open-source blockchain platform and...         Finished
# BTCD   Bitcoin Dark (BTCD) is a PoW and PoS hybrid al...              N/A
# CRAIG  CraigCoin (CRAIG) is a 100% pure PoS or Proof ...              N/A
#
#        ... BlockReward BlockTime AssetLaunchDate MaxSupply MktCapPenalty  \
# 42     ...           0         0      0000-00-00         0             0
# 365    ...         NaN       NaN             NaN       NaN           NaN
# 404    ...           0         0      0000-00-00         0             0
# 611    ...         NaN       NaN             NaN       NaN           NaN
# 808    ...           0         0      0000-00-00         0             0
# 1337   ...           0         0      0000-00-00         0             0
# 2015   ...         NaN       NaN             NaN       NaN           NaN
# NXT    ...           0         0      0000-00-00         0             0
# BTCD   ...         NaN       NaN             NaN       NaN           NaN
# CRAIG  ...         NaN       NaN             NaN       NaN           NaN
#
#       PlatformType BuiltOn SmartContractAddress Difficulty IsUsedInDefi
# 42             NaN     NaN                  NaN        NaN          NaN
# 365            NaN     NaN                  NaN        NaN          NaN
# 404            NaN     NaN                  NaN        NaN          NaN
# 611            NaN     NaN                  NaN        NaN          NaN
# 808            NaN     NaN                  NaN        NaN          NaN
# 1337           NaN     NaN                  NaN        NaN          NaN
# 2015           NaN     NaN                  NaN        NaN          NaN
# NXT            NaN     NaN                  NaN        NaN          NaN
# BTCD           NaN     NaN                  NaN        NaN          NaN
# CRAIG          NaN     NaN                  NaN        NaN          NaN
#
# [10 rows x 30 columns]

# %%
# Remove the "IsTrading" column

crypto_df.drop("IsTrading", axis=1, inplace=True)
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (1464, 29)
#           Id                    Url                           ImageUrl  \
# 42      4321     /coins/42/overview             /media/35650717/42.jpg
# 365    33639    /coins/365/overview              /media/352070/365.png
# 404    21227    /coins/404/overview    /media/35650851/404-300x300.jpg
# 611    20909    /coins/611/overview  /media/35650940/611-sixeleven.png
# 808    28223    /coins/808/overview              /media/351513/808.png
# 1337   20824   /coins/1337/overview          /media/35520987/elite.png
# 2015    3744   /coins/2015/overview              /media/20180/2015.png
# NXT     1183    /coins/nxt/overview               /media/20627/nxt.png
# BTCD    4400   /coins/btcd/overview            /media/19630/btcd_1.png
# CRAIG   4425  /coins/craig/overview             /media/20022/craig.png
#
#       ContentCreatedOn   Name Symbol     CoinName            FullName  \
# 42          1427211129     42     42      42 Coin        42 Coin (42)
# 365         1480032918    365    365      365Coin       365Coin (365)
# 404         1466100361    404    404      404Coin       404Coin (404)
# 611         1465914773    611    611    SixEleven     SixEleven (611)
# 808         1473980395    808    808          808           808 (808)
# 1337        1465838687   1337   1337    EliteCoin    EliteCoin (1337)
# 2015        1425316878   2015   2015    2015 coin    2015 coin (2015)
# NXT         1417635253    NXT    NXT          Nxt           Nxt (NXT)
# BTCD        1427711372   BTCD   BTCD  BitcoinDark  BitcoinDark (BTCD)
# CRAIG       1427711632  CRAIG  CRAIG   CraigsCoin  CraigsCoin (CRAIG)
#
#                                              Description AssetTokenStatus  \
# 42     Everything about 42 coin is 42 - apart from th...              N/A
# 365    365Coin is a Proof of Work and Proof of Stake ...              N/A
# 404    404 is a PoW/PoS hybrid cryptocurrency that al...              N/A
# 611    611 is a Namecoin based cryptocurrency, and it...              N/A
# 808    808 is a coin develop for the music community ...              N/A
# 1337   1337 coin was created as an experimental Proof...              N/A
# 2015   Twenty15 Coin was conceived to be an asset bac...              N/A
# NXT     Nxt is an open-source blockchain platform and...         Finished
# BTCD   Bitcoin Dark (BTCD) is a PoW and PoS hybrid al...              N/A
# CRAIG  CraigCoin (CRAIG) is a 100% pure PoS or Proof ...              N/A
#
#        ... BlockReward BlockTime AssetLaunchDate MaxSupply MktCapPenalty  \
# 42     ...           0         0      0000-00-00         0             0
# 365    ...         NaN       NaN             NaN       NaN           NaN
# 404    ...           0         0      0000-00-00         0             0
# 611    ...         NaN       NaN             NaN       NaN           NaN
# 808    ...           0         0      0000-00-00         0             0
# 1337   ...           0         0      0000-00-00         0             0
# 2015   ...         NaN       NaN             NaN       NaN           NaN
# NXT    ...           0         0      0000-00-00         0             0
# BTCD   ...         NaN       NaN             NaN       NaN           NaN
# CRAIG  ...         NaN       NaN             NaN       NaN           NaN
#
#       PlatformType BuiltOn SmartContractAddress Difficulty IsUsedInDefi
# 42             NaN     NaN                  NaN        NaN          NaN
# 365            NaN     NaN                  NaN        NaN          NaN
# 404            NaN     NaN                  NaN        NaN          NaN
# 611            NaN     NaN                  NaN        NaN          NaN
# 808            NaN     NaN                  NaN        NaN          NaN
# 1337           NaN     NaN                  NaN        NaN          NaN
# 2015           NaN     NaN                  NaN        NaN          NaN
# NXT            NaN     NaN                  NaN        NaN          NaN
# BTCD           NaN     NaN                  NaN        NaN          NaN
# CRAIG          NaN     NaN                  NaN        NaN          NaN
#
# [10 rows x 29 columns]

# %%
# Remove rows with at least 1 null value

crypto_df = crypto_df.dropna(axis=0, how="any")
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (0, 29)
# Empty DataFrame
# Columns: [Id, Url, ImageUrl, ContentCreatedOn, Name, Symbol, CoinName, FullName, Description, AssetTokenStatus, Algorithm, ProofType, SortOrder, Sponsored, Taxonomy, Rating, TotalCoinsMined, BlockNumber, NetHashesPerSecond, BlockReward, BlockTime, AssetLaunchDate, MaxSupply, MktCapPenalty, PlatformType, BuiltOn, SmartContractAddress, Difficulty, IsUsedInDefi]
# Index: []
#
# [0 rows x 29 columns]

# %%
# Remove rows with cryptocurrencies having no coins mined

crypto_df = crypto_df[crypto_df["TotalCoinsMined"] > 0]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (0, 29)
# Empty DataFrame
# Columns: [Id, Url, ImageUrl, ContentCreatedOn, Name, Symbol, CoinName, FullName, Description, AssetTokenStatus, Algorithm, ProofType, SortOrder, Sponsored, Taxonomy, Rating, TotalCoinsMined, BlockNumber, NetHashesPerSecond, BlockReward, BlockTime, AssetLaunchDate, MaxSupply, MktCapPenalty, PlatformType, BuiltOn, SmartContractAddress, Difficulty, IsUsedInDefi]
# Index: []
#
# [0 rows x 29 columns]

# %%
# Drop rows where there are 'N/A' text values

crypto_df = crypto_df[crypto_df.iloc[:] != 'N/A'].dropna()
crypto_df.head(10)
# Out:
# Empty DataFrame
# Columns: [Id, Url, ImageUrl, ContentCreatedOn, Name, Symbol, CoinName, FullName, Description, AssetTokenStatus, Algorithm, ProofType, SortOrder, Sponsored, Taxonomy, Rating, TotalCoinsMined, BlockNumber, NetHashesPerSecond, BlockReward, BlockTime, AssetLaunchDate, MaxSupply, MktCapPenalty, PlatformType, BuiltOn, SmartContractAddress, Difficulty, IsUsedInDefi]
# Index: []
#
# [0 rows x 29 columns]

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
coins_name = pd.DataFrame(crypto_df["CoinName"], index=crypto_df.index)
print(coins_name.shape)
coins_name.head()
# Out:
# (0, 1)
# Empty DataFrame
# Columns: [CoinName]
# Index: []

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df = crypto_df.drop("CoinName", axis=1)
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (0, 28)
# Empty DataFrame
# Columns: [Id, Url, ImageUrl, ContentCreatedOn, Name, Symbol, FullName, Description, AssetTokenStatus, Algorithm, ProofType, SortOrder, Sponsored, Taxonomy, Rating, TotalCoinsMined, BlockNumber, NetHashesPerSecond, BlockReward, BlockTime, AssetLaunchDate, MaxSupply, MktCapPenalty, PlatformType, BuiltOn, SmartContractAddress, Difficulty, IsUsedInDefi]
# Index: []
#
# [0 rows x 28 columns]

# %%
# Create dummy variables for text features
X = pd.get_dummies(data=crypto_df, columns=["Algorithm", "ProofType"])
print(X.shape)
X.head(10)
# Out:
# (0, 26)
# Empty DataFrame
# Columns: [Id, Url, ImageUrl, ContentCreatedOn, Name, Symbol, FullName, Description, AssetTokenStatus, SortOrder, Sponsored, Taxonomy, Rating, TotalCoinsMined, BlockNumber, NetHashesPerSecond, BlockReward, BlockTime, AssetLaunchDate, MaxSupply, MktCapPenalty, PlatformType, BuiltOn, SmartContractAddress, Difficulty, IsUsedInDefi]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Standardize data
X = StandardScaler().fit_transform(X)
X[:5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-dbb576b14000> in <module>
#       1 # Standardize data
# ----> 2 X = StandardScaler().fit_transform(X)
#       3 X[:5]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     665         # Reset internal state before fitting
#     666         self._reset()
# --> 667         return self.partial_fit(X, y)
#     668
#     669     def partial_fit(self, X, y=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     696         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     697                                 estimator=self, dtype=FLOAT_DTYPES,
# --> 698                                 force_all_finite='allow-nan')
#     699
#     700         # Even in the case of `with_mean=False`, we update the mean anyway
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     651                              " minimum of %d is required%s."
#     652                              % (n_samples, array.shape, ensure_min_samples,
# --> 653                                 context))
#     654
#     655     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 26)) while a minimum of 1 is required by StandardScaler.

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
n_comp = 3
pca = PCA(n_components=n_comp)
principal_components = pca.fit_transform(X)
principal_components
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-e8d4434fbb04> in <module>
#       2 n_comp = 3
#       3 pca = PCA(n_components=n_comp)
# ----> 4 principal_components = pca.fit_transform(X)
#       5 principal_components
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_pca.py in fit_transform(self, X, y)
#     374         C-ordered array, use 'np.ascontiguousarray'.
#     375         """
# --> 376         U, S, V = self._fit(X)
#     377         U = U[:, :self.n_components_]
#     378
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     396
#     397         X = self._validate_data(X, dtype=[np.float64, np.float32],
# --> 398                                 ensure_2d=True, copy=self.copy)
#     399
#     400         # Handle n_components==None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     651                              " minimum of %d is required%s."
#     652                              % (n_samples, array.shape, ensure_min_samples,
# --> 653                                 context))
#     654
#     655     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 26)) while a minimum of 1 is required.

# %%
# Create a DataFrame with the principal components data
col_names = [f"PC {i}" for i in range(1, n_comp + 1)]
pcs_df = pd.DataFrame(principal_components, columns=col_names, index=crypto_df.index)
print(pcs_df.shape)
pcs_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-75ab4c6e585b> in <module>
#       1 # Create a DataFrame with the principal components data
#       2 col_names = [f"PC {i}" for i in range(1, n_comp + 1)]
# ----> 3 pcs_df = pd.DataFrame(principal_components, columns=col_names, index=crypto_df.index)
#       4 print(pcs_df.shape)
#       5 pcs_df.head(10)
#
# NameError: name 'principal_components' is not defined

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-22ded3da320b> in <module>
#       5 for i in k:
#       6     km = KMeans(n_clusters=i, random_state=0)
# ----> 7     km.fit(pcs_df)
#       8     inertia.append(km.inertia_)
#       9
#
# NameError: name 'pcs_df' is not defined

# %% [markdown]
# Running K-Means with `k=<your best value for k here>`

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(pcs_df)

# Predict clusters
predictions = model.predict(pcs_df)

# Create a new DataFrame including predicted clusters and cryptocurrencies features
clustered_df = pd.concat([crypto_df, pcs_df], axis=1, sort=False)
clustered_df["CoinName"] = coins_name["CoinName"]
clustered_df["Class"] = model.labels_
print(clustered_df.shape)
clustered_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-13692d069ef2> in <module>
#       3
#       4 # Fit the model
# ----> 5 model.fit(pcs_df)
#       6
#       7 # Predict clusters
#
# NameError: name 'pcs_df' is not defined

# %% [markdown]
# ### Visualizing Results
#
# #### 3D-Scatter with Clusters

# %%
# Create a 3D-Scatter with the PCA data and the clusters
fig = px.scatter_3d(
    clustered_df,
    x="PC 1",
    y="PC 2",
    z="PC 3",
    color="Class",
    symbol="Class",
    hover_name="CoinName",
    hover_data=["Algorithm"],
    width=800,
)
fig.update_layout(legend=dict(x=0, y=1))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-e101672a5351> in <module>
#       1 # Create a 3D-Scatter with the PCA data and the clusters
#       2 fig = px.scatter_3d(
# ----> 3     clustered_df,
#       4     x="PC 1",
#       5     y="PC 2",
#
# NameError: name 'clustered_df' is not defined

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
clustered_df[
    [
        "CoinName",
        "Algorithm",
        "ProofType",
        "TotalCoinSupply",
        "TotalCoinsMined",
        "Class",
    ]
].hvplot.table()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-724663d54f1f> in <module>
#       1 # Table with tradable cryptos
# ----> 2 clustered_df[
#       3     [
#       4         "CoinName",
#       5         "Algorithm",
#
# NameError: name 'clustered_df' is not defined

# %%
# Print the total number of tradable cryptocurrencies
print(f"There are {clustered_df.shape[0]} tradable cryptocurrencies.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-2344b620f74d> in <module>
#       1 # Print the total number of tradable cryptocurrencies
# ----> 2 print(f"There are {clustered_df.shape[0]} tradable cryptocurrencies.")
#
# NameError: name 'clustered_df' is not defined

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
mm_scaler = MinMaxScaler()
plot_data = mm_scaler.fit_transform(
    clustered_df[["TotalCoinSupply", "TotalCoinsMined"]]
)
plot_df = pd.DataFrame(
    plot_data, columns=["TotalCoinSupply", "TotalCoinsMined"], index=clustered_df.index
)
plot_df["CoinName"] = clustered_df["CoinName"]
plot_df["Class"] = clustered_df["Class"]
plot_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-fe1441b5e978> in <module>
#       2 mm_scaler = MinMaxScaler()
#       3 plot_data = mm_scaler.fit_transform(
# ----> 4     clustered_df[["TotalCoinSupply", "TotalCoinsMined"]]
#       5 )
#       6 plot_df = pd.DataFrame(
#
# NameError: name 'clustered_df' is not defined

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
plot_df.hvplot.scatter(
    x="TotalCoinsMined", y="TotalCoinSupply", hover_cols=["CoinName"], by="Class"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-6fe831f639a2> in <module>
#       1 # Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
# ----> 2 plot_df.hvplot.scatter(
#       3     x="TotalCoinsMined", y="TotalCoinSupply", hover_cols=["CoinName"], by="Class"
#       4 )
#
# NameError: name 'plot_df' is not defined
