# %% [markdown]
#  # Clustering Crypto

# %% [markdown]
#  ## Installing External Libraries

# %%
# Install the altair plotting library: https://altair-viz.github.io/
# !pip install -U altair
# Out:
# Collecting altair
#   Downloading altair-4.1.0-py3-none-any.whl (727 kB)
#      |████████████████████████████████| 727 kB 8.6 MB/s eta 0:00:01     |█████▍                          | 122 kB 8.6 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: toolz in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from altair) (0.10.0)
# Requirement already satisfied, skipping upgrade: numpy in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from altair) (1.18.1)
# Requirement already satisfied, skipping upgrade: jinja2 in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from altair) (2.11.1)
# Requirement already satisfied, skipping upgrade: jsonschema in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from altair) (3.2.0)
# Requirement already satisfied, skipping upgrade: entrypoints in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from altair) (0.3)
# Requirement already satisfied, skipping upgrade: pandas>=0.18 in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from altair) (1.0.1)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from jinja2->altair) (0.23)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from jsonschema->altair) (19.3.0)
# Requirement already satisfied, skipping upgrade: six>=1.11.0 in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from jsonschema->altair) (1.14.0)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from jsonschema->altair) (0.15.7)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from jsonschema->altair) (1.5.0)
# Requirement already satisfied, skipping upgrade: setuptools in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from jsonschema->altair) (46.0.0.post20200309)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.18->altair) (2019.3)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /Users/kellyerogers/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema->altair) (2.2.0)
# Installing collected packages: altair
# Successfully installed altair-4.1.0

# %%
# Initial imports
import requests
import pandas as pd
import altair as alt
from pathlib import Path
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"
response = requests.get(url).json()

# %%
# Create a DataFrame
crypto_df = pd.DataFrame(response['Data']).T
crypto_df.head()
# Out:
#          Id                  Url                         ImageUrl  \
# 42     4321   /coins/42/overview           /media/35650717/42.jpg
# 300  749869  /coins/300/overview          /media/27010595/300.png
# 365   33639  /coins/365/overview            /media/352070/365.png
# 404   21227  /coins/404/overview  /media/35650851/404-300x300.jpg
# 433  926547  /coins/433/overview          /media/34836095/433.png
#
#     ContentCreatedOn Name Symbol   CoinName         FullName  \
# 42        1427211129   42     42    42 Coin     42 Coin (42)
# 300       1517935016  300    300  300 token  300 token (300)
# 365       1480032918  365    365    365Coin    365Coin (365)
# 404       1466100361  404    404    404Coin    404Coin (404)
# 433       1541597321  433    433  433 Token  433 Token (433)
#
#                                            Description AssetTokenStatus  ...  \
# 42   Everything about 42 coin is 42 - apart from th...              N/A  ...
# 300  300 token is an ERC20 token. This Token was cr...              N/A  ...
# 365  365Coin is a Proof of Work and Proof of Stake ...              N/A  ...
# 404  404 is a PoW/PoS hybrid cryptocurrency that al...              N/A  ...
# 433  433 Token is a decentralised soccer platform t...         Finished  ...
#
#     BlockReward BlockTime AssetLaunchDate MaxSupply MktCapPenalty  \
# 42            0         0      0000-00-00         0             0
# 300           0         0      2017-07-01        -1             0
# 365         NaN       NaN             NaN       NaN           NaN
# 404           0         0      0000-00-00         0             0
# 433         NaN       NaN             NaN       NaN           NaN
#
#     PlatformType BuiltOn                        SmartContractAddress  \
# 42           NaN     NaN                                         NaN
# 300        token     ETH  0xaec98a708810414878c3bcdf46aad31ded4a4557
# 365          NaN     NaN                                         NaN
# 404          NaN     NaN                                         NaN
# 433          NaN     NaN                                         NaN
#
#     Difficulty IsUsedInDefi
# 42         NaN          NaN
# 300        NaN          NaN
# 365        NaN          NaN
# 404        NaN          NaN
# 433        NaN          NaN
#
# [5 rows x 30 columns]

# %%
# Alternatively, use the provided csv file:
# file_path = Path("Resources/crypto_data.csv")

# Create a DataFrame
# crypto_df = pd.read_csv(file_path, index_col=0)
# crypto_df.head(10)

# %% [markdown]
#  ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
crypto_df=crypto_df[['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply']]
crypto_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-bd16e2043e76> in <module>
#       1 # Keep only necessary columns:
#       2 # 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply'
# ----> 3 crypto_df=crypto_df[['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','TotalCoinSupply']]
#       4 crypto_df.head(10)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1643             if not (self.name == "loc" and not raise_missing):
#    1644                 not_found = list(set(key) - set(ax))
# -> 1645                 raise KeyError(f"{not_found} not in index")
#    1646
#    1647             # we skip the warning on Categorical/Interval
#
# KeyError: "['TotalCoinSupply'] not in index"

# %%
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df[crypto_df["IsTrading"] == True]
print(crypto_df.shape)
crypto_df.head(10)

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df[crypto_df["Algorithm"] != "N/A"]
print(crypto_df.shape)
crypto_df.head(10)

# %%
# Remove the "IsTrading" column
crypto_df.drop("IsTrading", axis=1, inplace=True)
print(crypto_df.shape)
crypto_df.head(10)

# %%
# Remove rows with at least 1 null value
crypto_df = crypto_df.dropna(axis=0, how="any")
print(crypto_df.shape)
crypto_df.head(10)

# %%
# Remove rows with cryptocurrencies withouhaving no coins mined
crypto_df = crypto_df[crypto_df["TotalCoinsMined"] > 0]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (408, 30)
#           Id                   Url                           ImageUrl  \
# 300   749869   /coins/300/overview            /media/27010595/300.png
# MAID    5293  /coins/maid/overview             /media/352247/maid.png
# MONA    5296  /coins/mona/overview           /media/35309574/mona.png
# TRI     5341   /coins/tri/overview              /media/350568/tri.png
# DGD    18907   /coins/dgd/overview            /media/37305723/dgd.png
# BNT    22327   /coins/bnt/overview             /media/1383549/bnt.jpg
# KMD    26132   /coins/kmd/overview  /media/35651353/komodo300x300.jpg
# ARDR   30173  /coins/ardr/overview             /media/351736/ardr.png
# GNT    33022   /coins/gnt/overview       /media/351995/golem_logo.png
# MKR    41192   /coins/mkr/overview             /media/1382296/mkr.png
#
#      ContentCreatedOn  Name Symbol              CoinName  \
# 300        1517935016   300    300             300 token
# MAID       1430209540  MAID   MAID         MaidSafe Coin
# MONA       1430209574  MONA   MONA              MonaCoin
# TRI        1430210244   TRI    TRI        Triangles Coin
# DGD        1461915042   DGD    DGD             Digix DAO
# BNT        1467197288   BNT    BNT  Bancor Network Token
# KMD        1472484166   KMD    KMD                Komodo
# ARDR       1476417509  ARDR   ARDR                 Ardor
# GNT        1479426901   GNT    GNT   Golem Network Token
# MKR        1485505585   MKR    MKR                 Maker
#
#                         FullName  \
# 300              300 token (300)
# MAID        MaidSafe Coin (MAID)
# MONA             MonaCoin (MONA)
# TRI         Triangles Coin (TRI)
# DGD              Digix DAO (DGD)
# BNT   Bancor Network Token (BNT)
# KMD                 Komodo (KMD)
# ARDR                Ardor (ARDR)
# GNT    Golem Network Token (GNT)
# MKR                  Maker (MKR)
#
#                                             Description AssetTokenStatus  ...  \
# 300   300 token is an ERC20 token. This Token was cr...              N/A  ...
# MAID  MaidSafe is a fully decentralized platform on ...         Finished  ...
# MONA  Monacoin, conceived in December of 2013, is th...              N/A  ...
# TRI   Triangle is a PoW/PoS hybrid with a 33% annual...              N/A  ...
# DGD   Digix is an asset tokenization platform that p...         Finished  ...
# BNT   The Bancor Protocol is a blockchain-based syst...         Finished  ...
# KMD   Komodo is a privacy-centric cryptocurrency tha...         Finished  ...
# ARDR  Ardor is a multichain blockchain platform with...              N/A  ...
# GNT   The Golem Network is a decentralized computati...         Finished  ...
# MKR   Maker DAO is a decentralized autonomous organi...              N/A  ...
#
#      BlockReward BlockTime AssetLaunchDate  MaxSupply MktCapPenalty  \
# 300            0         0      2017-07-01         -1             0
# MAID           0         0      2014-06-12         -1             0
# MONA        12.5        94      2014-01-01         -1             0
# TRI            0         0      2014-10-11          0             0
# DGD            0         0      2016-04-28      2e+06             0
# BNT            0         0      2017-02-13         -1             0
# KMD            3        60      2016-09-13  200000000             0
# ARDR           0         0      2017-09-24  998999495             0
# GNT            0         0      2016-11-17         -1             0
# MKR            0         0      2015-08-15         -1             0
#
#      PlatformType BuiltOn                        SmartContractAddress  \
# 300         token     ETH  0xaec98a708810414878c3bcdf46aad31ded4a4557
# MAID   blockchain     NaN                                         NaN
# MONA   blockchain     NaN                                         NaN
# TRI           NaN     NaN                                         NaN
# DGD         token     ETH  0xe0b7927c4af23765cb51314a0e0521a9645f0e2a
# BNT         token     ETH  0x1f573d6fb3f13d689ff844b4ce37794d79a7ff1c
# KMD    blockchain     NaN                                         NaN
# ARDR   blockchain     NaN                                         NaN
# GNT         token     ETH  0xa74476443119A942dE498590Fe1f2454d7D4aC0d
# MKR           NaN     ETH  0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2
#
#        Difficulty IsUsedInDefi
# 300           NaN          NaN
# MAID          NaN          NaN
# MONA  3.27777e+06          NaN
# TRI       125.809          NaN
# DGD           NaN          NaN
# BNT           NaN          NaN
# KMD   1.97528e+08          NaN
# ARDR          NaN          NaN
# GNT           NaN          NaN
# MKR           NaN          NaN
#
# [10 rows x 30 columns]

# %%
# Drop rows where there are 'N/A' text values
crypto_df = crypto_df[crypto_df.iloc[:] != 'N/A'].dropna()
crypto_df.head(10)
# Out:
# Empty DataFrame
# Columns: [Id, Url, ImageUrl, ContentCreatedOn, Name, Symbol, CoinName, FullName, Description, AssetTokenStatus, Algorithm, ProofType, SortOrder, Sponsored, Taxonomy, Rating, IsTrading, TotalCoinsMined, BlockNumber, NetHashesPerSecond, BlockReward, BlockTime, AssetLaunchDate, MaxSupply, MktCapPenalty, PlatformType, BuiltOn, SmartContractAddress, Difficulty, IsUsedInDefi]
# Index: []
#
# [0 rows x 30 columns]

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
coins_name = pd.DataFrame(crypto_df["CoinName"], index=crypto_df.index)
print(coins_name.shape)
coins_name.head()
# Out:
# (0, 1)
# Empty DataFrame
# Columns: [CoinName]
# Index: []

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df = crypto_df.drop("CoinName", axis=1)
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (0, 29)
# Empty DataFrame
# Columns: [Id, Url, ImageUrl, ContentCreatedOn, Name, Symbol, FullName, Description, AssetTokenStatus, Algorithm, ProofType, SortOrder, Sponsored, Taxonomy, Rating, IsTrading, TotalCoinsMined, BlockNumber, NetHashesPerSecond, BlockReward, BlockTime, AssetLaunchDate, MaxSupply, MktCapPenalty, PlatformType, BuiltOn, SmartContractAddress, Difficulty, IsUsedInDefi]
# Index: []
#
# [0 rows x 29 columns]

# %%
# Create dummy variables for text features
X = pd.get_dummies(data=crypto_df, columns=["Algorithm", "ProofType"])
print(X.shape)
X.head(10)
# Out:
# (0, 27)
# Empty DataFrame
# Columns: [Id, Url, ImageUrl, ContentCreatedOn, Name, Symbol, FullName, Description, AssetTokenStatus, SortOrder, Sponsored, Taxonomy, Rating, IsTrading, TotalCoinsMined, BlockNumber, NetHashesPerSecond, BlockReward, BlockTime, AssetLaunchDate, MaxSupply, MktCapPenalty, PlatformType, BuiltOn, SmartContractAddress, Difficulty, IsUsedInDefi]
# Index: []
#
# [0 rows x 27 columns]

# %%
# Standardize data
X = StandardScaler().fit_transform(X)
X[:5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-dbb576b14000> in <module>
#       1 # Standardize data
# ----> 2 X = StandardScaler().fit_transform(X)
#       3 X[:5]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     665         # Reset internal state before fitting
#     666         self._reset()
# --> 667         return self.partial_fit(X, y)
#     668
#     669     def partial_fit(self, X, y=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     696         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     697                                 estimator=self, dtype=FLOAT_DTYPES,
# --> 698                                 force_all_finite='allow-nan')
#     699
#     700         # Even in the case of `with_mean=False`, we update the mean anyway
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     651                              " minimum of %d is required%s."
#     652                              % (n_samples, array.shape, ensure_min_samples,
# --> 653                                 context))
#     654
#     655     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 27)) while a minimum of 1 is required by StandardScaler.

# %% [markdown]
#  ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimension to 3 principal components
n_comp = 3
pca = PCA(n_components=n_comp)
principal_components = pca.fit_transform(X)
principal_components
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-b28c750ac604> in <module>
#       2 n_comp = 3
#       3 pca = PCA(n_components=n_comp)
# ----> 4 principal_components = pca.fit_transform(X)
#       5 principal_components
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_pca.py in fit_transform(self, X, y)
#     374         C-ordered array, use 'np.ascontiguousarray'.
#     375         """
# --> 376         U, S, V = self._fit(X)
#     377         U = U[:, :self.n_components_]
#     378
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     396
#     397         X = self._validate_data(X, dtype=[np.float64, np.float32],
# --> 398                                 ensure_2d=True, copy=self.copy)
#     399
#     400         # Handle n_components==None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     651                              " minimum of %d is required%s."
#     652                              % (n_samples, array.shape, ensure_min_samples,
# --> 653                                 context))
#     654
#     655     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 27)) while a minimum of 1 is required.

# %%
# Create a DataFrame with the principal components data
col_names = [f"PC {i}" for i in range(1, n_comp + 1)]
pcs_df = pd.DataFrame(principal_components, columns=col_names, index=crypto_df.index)
print(pcs_df.shape)
pcs_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-75ab4c6e585b> in <module>
#       1 # Create a DataFrame with the principal components data
#       2 col_names = [f"PC {i}" for i in range(1, n_comp + 1)]
# ----> 3 pcs_df = pd.DataFrame(principal_components, columns=col_names, index=crypto_df.index)
#       4 print(pcs_df.shape)
#       5 pcs_df.head(10)
#
# NameError: name 'principal_components' is not defined

# %% [markdown]
#  ### Clustering Crytocurrencies Using K-Means
#
#  #### Finde the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
alt.Chart(df_elbow).mark_line().encode(x="k", y="inertia")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5c0e845be062> in <module>
#       5 for i in k:
#       6     km = KMeans(n_clusters=i, random_state=0)
# ----> 7     km.fit(pcs_df)
#       8     inertia.append(km.inertia_)
#       9
#
# NameError: name 'pcs_df' is not defined

# %% [markdown]
#  Running K-Means with `k=4`

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(pcs_df)

# Predict clusters
predictions = model.predict(pcs_df)

# Create a new DataFrame including predicted clusters and cryptocurrencies features
clustered_df = pd.concat([crypto_df, pcs_df], axis=1, sort=False)
clustered_df["CoinName"] = coins_name["CoinName"]
clustered_df["Class"] = model.labels_
print(clustered_df.shape)
clustered_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-13692d069ef2> in <module>
#       3
#       4 # Fit the model
# ----> 5 model.fit(pcs_df)
#       6
#       7 # Predict clusters
#
# NameError: name 'pcs_df' is not defined

# %% [markdown]
#  ### Visualizing Results
#
#  #### Scatter Plot for Clusters

# %%
# Scatter plot to visualize clusters using two principal components
alt.Chart(clustered_df).mark_circle(size=60).encode(
    x="PC 1",
    y="PC 2",
    color=alt.Color(
        "Class",
        scale=alt.Scale(domain=[0, 1, 2, 3], range=["red", "green", "blue", "orange"]),
    ),
    tooltip=["CoinName", "Algorithm", "TotalCoinsMined", "TotalCoinSupply"],
).interactive()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-8cbfdbea6945> in <module>
#       1 # Scatter plot to visualize clusters using two principal components
# ----> 2 alt.Chart(clustered_df).mark_circle(size=60).encode(
#       3     x="PC 1",
#       4     y="PC 2",
#       5     color=alt.Color(
#
# NameError: name 'clustered_df' is not defined

# %% [markdown]
#  #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
mm_scaler = MinMaxScaler()
plot_data = mm_scaler.fit_transform(
    clustered_df[["TotalCoinSupply", "TotalCoinsMined"]]
)
plot_df = pd.DataFrame(
    plot_data, columns=["TotalCoinSupply", "TotalCoinsMined"], index=clustered_df.index
)
plot_df["CoinName"] = clustered_df["CoinName"]
plot_df["Class"] = clustered_df["Class"]
plot_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-59696083460b> in <module>
#       2 mm_scaler = MinMaxScaler()
#       3 plot_data = mm_scaler.fit_transform(
# ----> 4     clustered_df[["TotalCoinSupply", "TotalCoinsMined"]]
#       5 )
#       6 plot_df = pd.DataFrame(
#
# NameError: name 'clustered_df' is not defined

# %%
# Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
alt.Chart(plot_df).mark_circle(size=60).encode(
    x="TotalCoinsMined",
    y="TotalCoinSupply",
    color=alt.Color(
        "Class",
        scale=alt.Scale(domain=[0, 1, 2, 3], range=["red", "green", "blue", "orange"]),
    ),
    tooltip=["CoinName", "TotalCoinsMined", "TotalCoinSupply"],
).interactive()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-2375b89a8013> in <module>
#       1 # Plot the scatter with x="TotalCoinsMined" and y="TotalCoinSupply"
# ----> 2 alt.Chart(plot_df).mark_circle(size=60).encode(
#       3     x="TotalCoinsMined",
#       4     y="TotalCoinSupply",
#       5     color=alt.Color(
#
# NameError: name 'plot_df' is not defined

# %% [markdown]
#  #### Table of Tradable Cryptocurrencies

# %%
# Table with tradable cryptos
with pd.option_context("display.max_rows", None, "display.max_columns", None):
    display(
        clustered_df[
            [
                "CoinName",
                "Algorithm",
                "ProofType",
                "TotalCoinSupply",
                "TotalCoinsMined",
                "Class",
            ]
        ]
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-713cb6872386> in <module>
#       2 with pd.option_context("display.max_rows", None, "display.max_columns", None):
#       3     display(
# ----> 4         clustered_df[
#       5             [
#       6                 "CoinName",
#
# NameError: name 'clustered_df' is not defined
